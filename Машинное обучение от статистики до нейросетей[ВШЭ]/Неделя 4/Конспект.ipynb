# %% [markdown]
# **Гипотеза** - любое утверждение, которое мы собираемся проврить по данным
#
# __Что значит проверить гипотезу?__
#  - собрать данные
#  - любая выборка - случаная, просто посчитать описательные статистики недостаточно
#  - описательные статитики - случайные величины
#  - при любом объеме выборки можно допустить ошибку
