# %% [markdown]
# # Условное математическое

# %%
import pandas as pd
from IPython.display import Image

# %% [markdown]
# Ковариа́ция (корреляционный момент, ковариационный момент) — в теории вероятностей и математической статистике мера линейной зависимости двух случайных величин.

# %% [markdown]
# $E(y_i | x_i)$ --- это наилучший прогноз $y_i$, формулируемый с помощью $x_i$

# %%
Image(filename='фото//фото1.png')

# %% [markdown]
# $Var(s+h(r)∣r)=Var(s∣r)$

# %% [markdown]
#  При скалярном произведении равном ковариации, перпендикулярность и равенство косинуса нулю, и некоррелированность --- это одно и то же.

# %%
Image(filename='фото//фото2.png')

# %%
Image(filename='фото//фото3.png')
