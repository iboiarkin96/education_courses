# %%
from sys import platform
if platform == "linux" or platform == "linux2":
    print('Запуск на linux')
elif platform == "darwin":
    print('Запуск на Мак ОС')
elif platform == "win32":
    print('Запуск на windows')
# Out:
# Запуск на Мак ОС

# %%
from IPython.display import Image

# %%
Image(filename=f'''фото{'//' if platform == "win32" else '/'}снимок11.PNG''')

# %% [markdown]
# в питоне при делении получается float

# %% [markdown]
# лист - динамический ассоциативный массив

# %% [markdown]
# one-hot encoding (использование быстрого кодирования), что в мат смысле равносиельно
# наличию отдельного столбца для каждого признака. Это приводит к появлению очень сильно разряженных данных. Решение заключается в создании эмбендингов. Суть эмбендинга - сгруппировать слова со сходным значением

# %% [markdown]
# почему while медленее: оптимизатору проже идти по фору так как он проверяет меньше условий

# %% [markdown]
# Добавить или удалить элемент содержащийся в tuple нельзя, по причине всё той же неизменяемости.

# %% [markdown]
# Свя́зный спи́сок — базовая динамическая структура данных в информатике, состоящая из узлов, каждый из которых содержит как собственно данные, так и одну или две ссылки («связки») на следующий и/или предыдущий узел списка.

# %% [markdown]
# словари бысрее списков, так как там есть индессы (индексированная БД всегда бысрее чем обычная)

# %%
# ключи словаря- любой неизменяемый тип
d = {1: '2', 1:'2'}
d
# Out:
# {1: '2'}

# %%
d.update({'cat': 'leo'})
d
# Out:
# {1: '2', 'cat': 'leo'}

# %% [markdown]
# - полиморфизм - изменчивость. У каждого класса своя реализация своих методов.
# - инкапсуляция
# - абсракция
# - наслледование

# %% [markdown]
# https://regex101.com/

# %% [markdown]
# - скаляр - нуль мерный тензор
# - вектор - одномерный тензор
# - матрица - двузмерный тензор
