# %% [markdown]
# цель машинного обучения: предсказать по входным данным

# %%
from sys import platform
if platform == "linux" or platform == "linux2":
    print('Запуск на linux')
elif platform == "darwin":
    print('Запуск на Мак ОС')
elif platform == "win32":
    print('Запуск на windows')
# Out:
# Запуск на Мак ОС

# %%
pip install tensorflow 2

# %%
from IPython.display import Image

# %%
Image(filename=f'''фото{'//' if platform == "win32" else '/'}снимок12.PNG''')

# %%
Image(filename=f'''фото{'//' if platform == "win32" else '/'}снимок13.PNG''')

# %%
Image(filename=f'''фото{'//' if platform == "win32" else '/'}снимок13.PNG''')

# %%
Image(filename=f'''фото{'//' if platform == "win32" else '/'}снимок14.PNG''')

# %%
Image(filename=f'''фото{'//' if platform == "win32" else '/'}снимок15.PNG''')

# %%
Image(filename=f'''фото{'//' if platform == "win32" else '/'}снимок16.PNG''')

# %%
Image(filename=f'''фото{'//' if platform == "win32" else '/'}снимок17.PNG''')

# %%
Image(filename=f'''фото{'//' if platform == "win32" else '/'}снимок18.PNG''')

# %%
Image(filename=f'''фото{'//' if platform == "win32" else '/'}снимок19.PNG''')

# %%
Image(filename=f'''фото{'//' if platform == "win32" else '/'}снимок20.PNG''')

# %%
Image(filename=f'''фото{'//' if platform == "win32" else '/'}снимок21.PNG''')

# %%
Image(filename=f'''фото{'//' if platform == "win32" else '/'}снимок22.PNG''')

# %%
Image(filename=f'''фото{'//' if platform == "win32" else '/'}снимок23.PNG''')

# %%
Image(filename=f'''фото{'//' if platform == "win32" else '/'}снимок23.PNG''')

# %% [markdown]
#  - софт используется для мультиклассовой классификации
#  - каждый узел - это тест для атрибута в деревьях решений

# %%
Image(filename=f'''фото{'//' if platform == "win32" else '/'}снимок24.PNG''')

# %%
Image(filename=f'''фото{'//' if platform == "win32" else '/'}снимок25.PNG''')
