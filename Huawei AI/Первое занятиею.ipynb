# %%
from IPython.display import Image

# %%
Image(filename='''фото\\снимок1.PNG''')

# %% [markdown]
# [GPT-3](https://ru.wikipedia.org/wiki/GPT-3)
#
# [Дали от сбера](https://habr.com/ru/news/t/586894/)
#
# [Про тьюринга](https://habr.com/ru/company/ua-hosting/blog/471308/)

# %% [markdown]
# тест тьюринга:
#  - человек может выявить человек это или ИИ

# %% [markdown]
# джон маккарти в 1956  предложил термин ИИ

# %%
Image(filename='''фото\\снимок2.PNG''')

# %%
Image(filename='''фото\\снимок3.PNG''')

# %%
Image(filename='''фото\\снимок4.PNG''')

# %% [markdown]
# * deep blue (IBM) обыграл Каспарова в шагматы
#
# * alphaGo(Google TPU) обыграла Ли Седола

# %% [markdown]
# при работк с sheech processing
# - проблема сематинки
# - эхоподавление

# %% [markdown]
# использование разметки для computer vision

# %% [markdown]
# алгоритмы
# - гармонический анализ(фурье транформация и вейвлет трасформация)
# - теория вероятности
# - статистика
# - функциональный анализ

# %% [markdown]
# - 30,11,2021 с 12-16
# - 01.12.2021 с 11-15
# - 02.12.2021 с 11-15
# - 03.12.2021 с 10-14

# %%
Image(filename='''фото\\снимок5.PNG''')

# %%
Image(filename='''фото\\снимок6.PNG''')

# %% [markdown]
# - генетические алгоритмы
# - выпуклая оптимизация/ невыпуклая оптиммизация

# %% [markdown]
# - Функционал data mining строго ограничен сбором информации с разных ресурсов. Сама технология не принимает решения и не способна делать какие-то действия без участия человека. Основная цель – поиск полезных способов применения данных, которые были найдены.
# - Machine learning работает с массивами данных, которые технология data mining сформировала. С помощью заранее смоделированных алгоритмов действий, технология ИИ использует данные для принятия решений и последующих действий. Без постоянного бекапа актуальной информации эта технология не существует.

# %% [markdown]
# [отличие data maining and mashine lerning](https://www.simplilearn.com/data-mining-vs-machine-learning-article)

# %%
Image(filename='''фото\\снимок7.PNG''')

# %% [markdown]
# Data mining involves six common classes of tasks:
#
# - Anomaly detection (outlier/change/deviation detection) – The identification of unusual data records, that might be interesting or data errors that require further investigation.
# - Association rule learning (dependency modeling) – Searches for relationships between variables. For example, a supermarket might gather data on customer purchasing habits. Using association rule learning, the supermarket can determine which products are frequently bought together and use this information for marketing purposes. This is sometimes referred to as market basket analysis.
# - Clustering – is the task of discovering groups and structures in the data that are in some way or another "similar", without using known structures in the data.
# - Classification – is the task of generalizing known structure to apply to new data. For example, an e-mail program might attempt to classify an e-mail as "legitimate" or as "spam".
# - Regression – attempts to find a function that models the data with the least error that is, for estimating the relationships among data or datasets.
# - Summarization – providing a more compact representation of the data set, including visualization and report generation.

# %% [markdown]
# - Про очистку — это data cleansing, data wrangling
# -  дата майнинга как процесса извлечения знаний из данных (Пятецкий-Шапиро)
# -  машинного обучения как класса алгоритмов, обучающихся предсказывать неизвестные данные на основе известных,

# %%
Image(filename='''фото\\снимок8.PNG''')

# %% [markdown]
# python - glue language

# %%
Image(filename='''фото\\снимок9.PNG''')

# %%
Image(filename='''фото\\снимок10.PNG''')
